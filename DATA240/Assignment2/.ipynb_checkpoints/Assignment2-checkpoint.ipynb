# %% [markdown]
# # Assignment 2
# ## Sungwon Lee
# ### 017473950

# %% [markdown]
# ## 1. (3 pts) Implanting K-means clustering algorithm

# %%
# Import only basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm


df = pd.read_csv('cluster_data1.csv')
df.head()
# Out:
#     X1   X2   X3   X4
# 0  6.7  3.0  5.0  1.7
# 1  6.3  2.9  5.6  1.8
# 2  5.6  3.0  4.5  1.5
# 3  7.6  3.0  6.6  2.1
# 4  6.0  3.4  4.5  1.6

# %%
X = df[['X1', 'X2']].values  # We will use X1 and X2 for 2D plotting

def initialize_centroids(X, k):
    """Randomly initialize centroids from the dataset."""
    centroids = X[np.random.choice(X.shape[0], k, replace=False)]
    return centroids

def compute_distances(X, centroids):
    """Compute the Euclidean distance between each data point and each centroid."""
    distances = np.zeros((X.shape[0], centroids.shape[0]))
    for i in range(centroids.shape[0]):
        distances[:, i] = np.linalg.norm(X - centroids[i], axis=1)
    return distances

def update_centroids(X, labels, k):
    """Recompute centroids as the mean of the points assigned to each cluster."""
    new_centroids = np.zeros((k, X.shape[1]))
    for i in range(k):
        points_in_cluster = X[labels == i]
        if len(points_in_cluster) > 0:
            new_centroids[i] = points_in_cluster.mean(axis=0)
    return new_centroids

def plot_clusters(X, centroids, labels, iteration):
    """Plot the clusters and centroids."""
    plt.figure(figsize=(8, 6))
    
    # Plot each cluster
    for i in range(centroids.shape[0]):
        plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], label=f'Cluster {i+1}')
    
    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
    
    plt.title(f'K-Means Clustering - Iteration {iteration}')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    plt.grid(True)
    plt.show()

def kmeans(X, k, max_iterations=5, tolerance=1e-4):
    """K-Means Clustering algorithm."""
    centroids = initialize_centroids(X, k)
    
    for iteration in range(max_iterations + 1):
        # Step 1: Assign clusters
        distances = compute_distances(X, centroids)
        labels = np.argmin(distances, axis=1)  # Assign each point to the closest centroid
        
        # Plot the clusters and centroids for the first 5 steps
        plot_clusters(X, centroids, labels, iteration)
        
        # Step 2: Recompute centroids
        new_centroids = update_centroids(X, labels, k)
        
        # Step 3: Check for convergence (if centroids change by less than tolerance)
        if np.linalg.norm(new_centroids - centroids) < tolerance:
            print(f"Converged at iteration {iteration}")
            break
        
        centroids = new_centroids

# Run K-Means algorithm with K=3 and plot results for the first 5 steps
kmeans(X, k=3)

# %%
from sklearn.cluster import KMeans


# Initialize and fit the KMeans model from scikit-learn
kmeans = KMeans(n_clusters=3, random_state=123, max_iter=5)

# Fit the model
kmeans.fit(X)

# Get the cluster labels and centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot the results
def plot_clusters(X, centroids, labels, iteration='Final'):
    """Plot the clusters and centroids."""
    plt.figure(figsize=(8, 6))
    
    # Plot each cluster
    for i in range(centroids.shape[0]):
        plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], label=f'Cluster {i+1}')
    
    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
    
    plt.title(f'K-Means Clustering (scikit-learn) - {iteration}')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the final result
plot_clusters(X, centroids, labels)
# Out:
# C:\Users\pumad\anaconda3\envs\myenv\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # 2. (3 pts) Implanting K-means++ clustering algorithm and finding K
