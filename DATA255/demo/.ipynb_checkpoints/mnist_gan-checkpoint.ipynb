# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 107203628.60it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 6671569.85it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 31406034.25it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 21796943.67it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([9, 2, 6, 9, 9, 9, 1, 2, 4, 7, 2, 0, 6, 5, 9, 7, 6, 9, 9, 8, 2, 5, 3, 6,
#         2, 8, 2, 9, 8, 8, 2, 3, 3, 1, 1, 7, 9, 7, 0, 5, 0, 3, 9, 9, 2, 2, 7, 1,
#         2, 8, 4, 6, 0, 8, 1, 6, 3, 0, 5, 5, 9, 2, 0, 1, 7, 9, 0, 8, 8, 4, 3, 3,
#         4, 7, 2, 8, 3, 2, 5, 4, 5, 5, 7, 1, 0, 1, 6, 0, 4, 7, 2, 8, 7, 3, 7, 8,
#         6, 9, 1, 1])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0668, g_loss: 3.9446, D(x): 0.99, D(G(z)): 0.05
# Epoch [0/300], Step [400/600], d_loss: 0.0659, g_loss: 5.3361, D(x): 0.98, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.1060, g_loss: 4.6546, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0851, g_loss: 5.6524, D(x): 0.94, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.2539, g_loss: 3.6966, D(x): 0.95, D(G(z)): 0.14
# Epoch [1/300], Step [600/600], d_loss: 0.4895, g_loss: 3.4054, D(x): 0.82, D(G(z)): 0.07
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.0405, g_loss: 5.3208, D(x): 0.98, D(G(z)): 0.01
# Epoch [2/300], Step [400/600], d_loss: 0.6652, g_loss: 2.7489, D(x): 0.83, D(G(z)): 0.22
# Epoch [2/300], Step [600/600], d_loss: 0.1278, g_loss: 4.0797, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.8567, g_loss: 2.0545, D(x): 0.74, D(G(z)): 0.29
# Epoch [3/300], Step [400/600], d_loss: 0.9202, g_loss: 1.9114, D(x): 0.80, D(G(z)): 0.37
# Epoch [3/300], Step [600/600], d_loss: 1.5054, g_loss: 2.0025, D(x): 0.63, D(G(z)): 0.39
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.3224, g_loss: 2.8268, D(x): 0.90, D(G(z)): 0.14
# Epoch [4/300], Step [400/600], d_loss: 0.8845, g_loss: 1.7791, D(x): 0.86, D(G(z)): 0.45
# Epoch [4/300], Step [600/600], d_loss: 0.6145, g_loss: 2.2523, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.3005, g_loss: 3.2792, D(x): 0.89, D(G(z)): 0.11
# Epoch [5/300], Step [400/600], d_loss: 0.3753, g_loss: 2.6771, D(x): 0.89, D(G(z)): 0.11
# Epoch [5/300], Step [600/600], d_loss: 0.5275, g_loss: 2.3859, D(x): 0.87, D(G(z)): 0.16
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.2088, g_loss: 5.2175, D(x): 0.91, D(G(z)): 0.03
# Epoch [6/300], Step [400/600], d_loss: 0.2988, g_loss: 4.5603, D(x): 0.92, D(G(z)): 0.12
# Epoch [6/300], Step [600/600], d_loss: 0.2096, g_loss: 6.4040, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.3648, g_loss: 3.9500, D(x): 0.84, D(G(z)): 0.06
# Epoch [7/300], Step [400/600], d_loss: 0.6225, g_loss: 4.2627, D(x): 0.89, D(G(z)): 0.23
# Epoch [7/300], Step [600/600], d_loss: 0.2146, g_loss: 4.9523, D(x): 0.94, D(G(z)): 0.08
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.6189, g_loss: 3.2592, D(x): 0.81, D(G(z)): 0.11
# Epoch [8/300], Step [400/600], d_loss: 0.5256, g_loss: 3.1068, D(x): 0.86, D(G(z)): 0.20
# Epoch [8/300], Step [600/600], d_loss: 0.1797, g_loss: 5.1551, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.2635, g_loss: 4.8326, D(x): 0.89, D(G(z)): 0.04
# Epoch [9/300], Step [400/600], d_loss: 0.1945, g_loss: 4.5693, D(x): 0.96, D(G(z)): 0.10
# Epoch [9/300], Step [600/600], d_loss: 0.1944, g_loss: 3.3959, D(x): 0.97, D(G(z)): 0.13
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0976, g_loss: 4.7380, D(x): 0.96, D(G(z)): 0.03
# Epoch [10/300], Step [400/600], d_loss: 0.1443, g_loss: 5.2244, D(x): 0.93, D(G(z)): 0.02
# Epoch [10/300], Step [600/600], d_loss: 0.5772, g_loss: 4.5873, D(x): 0.99, D(G(z)): 0.34
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1538, g_loss: 6.0512, D(x): 0.93, D(G(z)): 0.04
# Epoch [11/300], Step [400/600], d_loss: 0.2393, g_loss: 4.7418, D(x): 0.94, D(G(z)): 0.08
# Epoch [11/300], Step [600/600], d_loss: 0.1068, g_loss: 3.9788, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1519, g_loss: 5.5646, D(x): 0.97, D(G(z)): 0.06
# Epoch [12/300], Step [400/600], d_loss: 0.1628, g_loss: 5.4798, D(x): 0.97, D(G(z)): 0.08
# Epoch [12/300], Step [600/600], d_loss: 0.0530, g_loss: 8.1436, D(x): 0.97, D(G(z)): 0.01
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.0541, g_loss: 7.0701, D(x): 0.97, D(G(z)): 0.01
# Epoch [13/300], Step [400/600], d_loss: 0.2226, g_loss: 7.9913, D(x): 0.91, D(G(z)): 0.00
# Epoch [13/300], Step [600/600], d_loss: 0.1535, g_loss: 4.9276, D(x): 0.97, D(G(z)): 0.08
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.3161, g_loss: 5.2552, D(x): 0.92, D(G(z)): 0.04
# Epoch [14/300], Step [400/600], d_loss: 0.0784, g_loss: 6.3531, D(x): 0.99, D(G(z)): 0.06
# Epoch [14/300], Step [600/600], d_loss: 0.0492, g_loss: 6.2117, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.0681, g_loss: 5.1506, D(x): 0.97, D(G(z)): 0.03
# Epoch [15/300], Step [400/600], d_loss: 0.1932, g_loss: 7.0999, D(x): 0.96, D(G(z)): 0.07
# Epoch [15/300], Step [600/600], d_loss: 0.2094, g_loss: 6.4681, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.0928, g_loss: 5.2012, D(x): 0.98, D(G(z)): 0.05
# Epoch [16/300], Step [400/600], d_loss: 0.2729, g_loss: 7.9098, D(x): 0.91, D(G(z)): 0.03
# Epoch [16/300], Step [600/600], d_loss: 0.2047, g_loss: 5.8579, D(x): 0.97, D(G(z)): 0.11
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.1901, g_loss: 4.8793, D(x): 0.97, D(G(z)): 0.11
# Epoch [17/300], Step [400/600], d_loss: 0.0889, g_loss: 5.7454, D(x): 0.97, D(G(z)): 0.04
# Epoch [17/300], Step [600/600], d_loss: 0.2463, g_loss: 4.6635, D(x): 0.94, D(G(z)): 0.11
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.1544, g_loss: 4.6115, D(x): 0.97, D(G(z)): 0.09
# Epoch [18/300], Step [400/600], d_loss: 0.1216, g_loss: 6.4606, D(x): 0.97, D(G(z)): 0.05
# Epoch [18/300], Step [600/600], d_loss: 0.0936, g_loss: 4.4973, D(x): 0.98, D(G(z)): 0.06
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2436, g_loss: 6.6020, D(x): 0.97, D(G(z)): 0.14
# Epoch [19/300], Step [400/600], d_loss: 0.1561, g_loss: 5.5729, D(x): 0.94, D(G(z)): 0.02
# Epoch [19/300], Step [600/600], d_loss: 0.4712, g_loss: 6.1445, D(x): 0.86, D(G(z)): 0.03
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.3607, g_loss: 3.4248, D(x): 0.93, D(G(z)): 0.12
# Epoch [20/300], Step [400/600], d_loss: 0.3450, g_loss: 3.9079, D(x): 0.90, D(G(z)): 0.04
# Epoch [20/300], Step [600/600], d_loss: 0.3484, g_loss: 5.3177, D(x): 0.88, D(G(z)): 0.05
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1106, g_loss: 4.7165, D(x): 0.97, D(G(z)): 0.06
# Epoch [21/300], Step [400/600], d_loss: 0.2531, g_loss: 5.5987, D(x): 0.95, D(G(z)): 0.08
# Epoch [21/300], Step [600/600], d_loss: 0.3028, g_loss: 5.6691, D(x): 0.92, D(G(z)): 0.06
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.3508, g_loss: 4.0299, D(x): 0.91, D(G(z)): 0.09
# Epoch [22/300], Step [400/600], d_loss: 0.4005, g_loss: 4.3203, D(x): 0.90, D(G(z)): 0.11
# Epoch [22/300], Step [600/600], d_loss: 0.2501, g_loss: 3.7509, D(x): 0.91, D(G(z)): 0.04
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.4029, g_loss: 4.8274, D(x): 0.90, D(G(z)): 0.06
# Epoch [23/300], Step [400/600], d_loss: 0.2667, g_loss: 4.5185, D(x): 0.91, D(G(z)): 0.03
# Epoch [23/300], Step [600/600], d_loss: 0.5789, g_loss: 5.2316, D(x): 0.83, D(G(z)): 0.04
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3452, g_loss: 5.1069, D(x): 0.92, D(G(z)): 0.12
# Epoch [24/300], Step [400/600], d_loss: 0.3575, g_loss: 4.4875, D(x): 0.85, D(G(z)): 0.04
# Epoch [24/300], Step [600/600], d_loss: 0.2832, g_loss: 4.0437, D(x): 0.92, D(G(z)): 0.09
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.3648, g_loss: 4.0785, D(x): 0.91, D(G(z)): 0.14
# Epoch [25/300], Step [400/600], d_loss: 0.3637, g_loss: 3.0584, D(x): 0.90, D(G(z)): 0.14
# Epoch [25/300], Step [600/600], d_loss: 0.4776, g_loss: 2.9869, D(x): 0.89, D(G(z)): 0.20
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2772, g_loss: 4.0297, D(x): 0.92, D(G(z)): 0.09
# Epoch [26/300], Step [400/600], d_loss: 0.3112, g_loss: 3.3608, D(x): 0.92, D(G(z)): 0.14
# Epoch [26/300], Step [600/600], d_loss: 0.4718, g_loss: 4.3838, D(x): 0.85, D(G(z)): 0.03
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.3200, g_loss: 4.9122, D(x): 0.91, D(G(z)): 0.07
# Epoch [27/300], Step [400/600], d_loss: 0.4495, g_loss: 4.4824, D(x): 0.92, D(G(z)): 0.17
# Epoch [27/300], Step [600/600], d_loss: 0.3716, g_loss: 3.6612, D(x): 0.93, D(G(z)): 0.16
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.2898, g_loss: 3.8280, D(x): 0.89, D(G(z)): 0.06
# Epoch [28/300], Step [400/600], d_loss: 0.4123, g_loss: 4.1426, D(x): 0.91, D(G(z)): 0.15
# Epoch [28/300], Step [600/600], d_loss: 0.4217, g_loss: 3.5265, D(x): 0.95, D(G(z)): 0.21
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.3165, g_loss: 4.0595, D(x): 0.88, D(G(z)): 0.08
# Epoch [29/300], Step [400/600], d_loss: 0.3541, g_loss: 3.3973, D(x): 0.91, D(G(z)): 0.14
# Epoch [29/300], Step [600/600], d_loss: 0.3453, g_loss: 3.0473, D(x): 0.94, D(G(z)): 0.14
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.2990, g_loss: 4.2523, D(x): 0.94, D(G(z)): 0.15
# Epoch [30/300], Step [400/600], d_loss: 0.3436, g_loss: 4.2921, D(x): 0.86, D(G(z)): 0.04
# Epoch [30/300], Step [600/600], d_loss: 0.3663, g_loss: 3.6710, D(x): 0.90, D(G(z)): 0.12
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4533, g_loss: 3.4124, D(x): 0.90, D(G(z)): 0.14
# Epoch [31/300], Step [400/600], d_loss: 0.3480, g_loss: 3.6004, D(x): 0.89, D(G(z)): 0.11
# Epoch [31/300], Step [600/600], d_loss: 0.3242, g_loss: 3.2682, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.4420, g_loss: 2.9553, D(x): 0.82, D(G(z)): 0.07
# Epoch [32/300], Step [400/600], d_loss: 0.2915, g_loss: 3.0221, D(x): 0.93, D(G(z)): 0.15
# Epoch [32/300], Step [600/600], d_loss: 0.3779, g_loss: 3.9660, D(x): 0.91, D(G(z)): 0.14
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.4571, g_loss: 4.0611, D(x): 0.85, D(G(z)): 0.08
# Epoch [33/300], Step [400/600], d_loss: 0.2854, g_loss: 4.0694, D(x): 0.91, D(G(z)): 0.09
# Epoch [33/300], Step [600/600], d_loss: 0.3637, g_loss: 3.9207, D(x): 0.93, D(G(z)): 0.16
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.5714, g_loss: 3.5236, D(x): 0.95, D(G(z)): 0.27
# Epoch [34/300], Step [400/600], d_loss: 0.4201, g_loss: 2.7810, D(x): 0.89, D(G(z)): 0.15
# Epoch [34/300], Step [600/600], d_loss: 0.4574, g_loss: 4.1789, D(x): 0.91, D(G(z)): 0.18
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4133, g_loss: 5.1564, D(x): 0.89, D(G(z)): 0.11
# Epoch [35/300], Step [400/600], d_loss: 0.3917, g_loss: 3.5338, D(x): 0.92, D(G(z)): 0.14
# Epoch [35/300], Step [600/600], d_loss: 0.5550, g_loss: 3.6548, D(x): 0.95, D(G(z)): 0.28
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.5001, g_loss: 3.1613, D(x): 0.85, D(G(z)): 0.12
# Epoch [36/300], Step [400/600], d_loss: 0.4233, g_loss: 3.7691, D(x): 0.86, D(G(z)): 0.11
# Epoch [36/300], Step [600/600], d_loss: 0.4230, g_loss: 4.2172, D(x): 0.85, D(G(z)): 0.09
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.3128, g_loss: 4.1998, D(x): 0.92, D(G(z)): 0.13
# Epoch [37/300], Step [400/600], d_loss: 0.5651, g_loss: 2.7178, D(x): 0.84, D(G(z)): 0.16
# Epoch [37/300], Step [600/600], d_loss: 0.5326, g_loss: 3.0834, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.5189, g_loss: 2.5062, D(x): 0.86, D(G(z)): 0.16
# Epoch [38/300], Step [400/600], d_loss: 0.4281, g_loss: 4.7767, D(x): 0.91, D(G(z)): 0.18
# Epoch [38/300], Step [600/600], d_loss: 0.3911, g_loss: 3.8308, D(x): 0.83, D(G(z)): 0.06
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.6041, g_loss: 3.3823, D(x): 0.83, D(G(z)): 0.17
# Epoch [39/300], Step [400/600], d_loss: 0.4541, g_loss: 2.2382, D(x): 0.90, D(G(z)): 0.18
# Epoch [39/300], Step [600/600], d_loss: 0.3545, g_loss: 3.0708, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.4495, g_loss: 3.9251, D(x): 0.82, D(G(z)): 0.06
# Epoch [40/300], Step [400/600], d_loss: 0.1888, g_loss: 5.2175, D(x): 0.94, D(G(z)): 0.09
# Epoch [40/300], Step [600/600], d_loss: 0.3877, g_loss: 3.7319, D(x): 0.88, D(G(z)): 0.11
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.4454, g_loss: 2.9771, D(x): 0.88, D(G(z)): 0.14
# Epoch [41/300], Step [400/600], d_loss: 0.5200, g_loss: 4.0120, D(x): 0.84, D(G(z)): 0.11
# Epoch [41/300], Step [600/600], d_loss: 0.3788, g_loss: 2.0477, D(x): 0.86, D(G(z)): 0.11
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.5765, g_loss: 3.0649, D(x): 0.85, D(G(z)): 0.17
# Epoch [42/300], Step [400/600], d_loss: 0.4518, g_loss: 2.7929, D(x): 0.86, D(G(z)): 0.16
# Epoch [42/300], Step [600/600], d_loss: 0.4452, g_loss: 4.1829, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.3681, g_loss: 3.6565, D(x): 0.92, D(G(z)): 0.17
# Epoch [43/300], Step [400/600], d_loss: 0.5991, g_loss: 4.0311, D(x): 0.81, D(G(z)): 0.06
# Epoch [43/300], Step [600/600], d_loss: 0.3496, g_loss: 3.1355, D(x): 0.96, D(G(z)): 0.19
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5449, g_loss: 3.4800, D(x): 0.87, D(G(z)): 0.18
# Epoch [44/300], Step [400/600], d_loss: 0.2777, g_loss: 3.4712, D(x): 0.90, D(G(z)): 0.11
# Epoch [44/300], Step [600/600], d_loss: 0.4544, g_loss: 3.3884, D(x): 0.86, D(G(z)): 0.11
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.3561, g_loss: 3.8108, D(x): 0.89, D(G(z)): 0.10
# Epoch [45/300], Step [400/600], d_loss: 0.3666, g_loss: 3.6477, D(x): 0.91, D(G(z)): 0.17
# Epoch [45/300], Step [600/600], d_loss: 0.5002, g_loss: 2.5683, D(x): 0.91, D(G(z)): 0.26
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.4570, g_loss: 3.8116, D(x): 0.85, D(G(z)): 0.09
# Epoch [46/300], Step [400/600], d_loss: 0.3836, g_loss: 2.5545, D(x): 0.85, D(G(z)): 0.11
# Epoch [46/300], Step [600/600], d_loss: 0.4675, g_loss: 2.9114, D(x): 0.84, D(G(z)): 0.08
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4268, g_loss: 2.4459, D(x): 0.87, D(G(z)): 0.14
# Epoch [47/300], Step [400/600], d_loss: 0.5262, g_loss: 2.8681, D(x): 0.83, D(G(z)): 0.15
# Epoch [47/300], Step [600/600], d_loss: 0.5125, g_loss: 2.4387, D(x): 0.81, D(G(z)): 0.10
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.4110, g_loss: 2.6696, D(x): 0.91, D(G(z)): 0.19
# Epoch [48/300], Step [400/600], d_loss: 0.5774, g_loss: 3.2205, D(x): 0.80, D(G(z)): 0.09
# Epoch [48/300], Step [600/600], d_loss: 0.4623, g_loss: 2.0818, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.5038, g_loss: 3.2658, D(x): 0.81, D(G(z)): 0.12
# Epoch [49/300], Step [400/600], d_loss: 0.4230, g_loss: 2.5068, D(x): 0.83, D(G(z)): 0.11
# Epoch [49/300], Step [600/600], d_loss: 0.4246, g_loss: 3.4677, D(x): 0.84, D(G(z)): 0.07
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.8326, g_loss: 3.2546, D(x): 0.76, D(G(z)): 0.15
# Epoch [50/300], Step [400/600], d_loss: 0.4447, g_loss: 2.6183, D(x): 0.94, D(G(z)): 0.24
# Epoch [50/300], Step [600/600], d_loss: 0.7409, g_loss: 3.1819, D(x): 0.79, D(G(z)): 0.16
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.6274, g_loss: 3.2400, D(x): 0.78, D(G(z)): 0.13
# Epoch [51/300], Step [400/600], d_loss: 0.5837, g_loss: 2.7942, D(x): 0.92, D(G(z)): 0.29
# Epoch [51/300], Step [600/600], d_loss: 0.4452, g_loss: 4.0002, D(x): 0.86, D(G(z)): 0.12
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.6124, g_loss: 3.2569, D(x): 0.74, D(G(z)): 0.05
# Epoch [52/300], Step [400/600], d_loss: 0.3881, g_loss: 3.0465, D(x): 0.89, D(G(z)): 0.17
# Epoch [52/300], Step [600/600], d_loss: 0.3857, g_loss: 4.1209, D(x): 0.89, D(G(z)): 0.09
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.8620, g_loss: 1.8378, D(x): 0.87, D(G(z)): 0.33
# Epoch [53/300], Step [400/600], d_loss: 0.5894, g_loss: 3.3452, D(x): 0.80, D(G(z)): 0.15
# Epoch [53/300], Step [600/600], d_loss: 0.4322, g_loss: 2.9212, D(x): 0.89, D(G(z)): 0.18
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.3525, g_loss: 3.5522, D(x): 0.85, D(G(z)): 0.10
# Epoch [54/300], Step [400/600], d_loss: 0.3921, g_loss: 2.7290, D(x): 0.85, D(G(z)): 0.07
# Epoch [54/300], Step [600/600], d_loss: 0.4120, g_loss: 2.6076, D(x): 0.89, D(G(z)): 0.18
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.4103, g_loss: 2.8786, D(x): 0.87, D(G(z)): 0.15
# Epoch [55/300], Step [400/600], d_loss: 0.5660, g_loss: 2.0082, D(x): 0.91, D(G(z)): 0.29
# Epoch [55/300], Step [600/600], d_loss: 0.5628, g_loss: 2.4870, D(x): 0.90, D(G(z)): 0.26
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.4936, g_loss: 3.0223, D(x): 0.87, D(G(z)): 0.22
# Epoch [56/300], Step [400/600], d_loss: 1.0724, g_loss: 2.1505, D(x): 0.60, D(G(z)): 0.10
# Epoch [56/300], Step [600/600], d_loss: 0.5345, g_loss: 2.5743, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.6322, g_loss: 3.0192, D(x): 0.82, D(G(z)): 0.20
# Epoch [57/300], Step [400/600], d_loss: 0.4723, g_loss: 2.3389, D(x): 0.82, D(G(z)): 0.15
# Epoch [57/300], Step [600/600], d_loss: 0.7961, g_loss: 2.1240, D(x): 0.69, D(G(z)): 0.09
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.5176, g_loss: 2.2435, D(x): 0.85, D(G(z)): 0.21
# Epoch [58/300], Step [400/600], d_loss: 0.6415, g_loss: 1.7420, D(x): 0.81, D(G(z)): 0.19
# Epoch [58/300], Step [600/600], d_loss: 0.8123, g_loss: 2.5119, D(x): 0.71, D(G(z)): 0.17
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.6364, g_loss: 3.1470, D(x): 0.83, D(G(z)): 0.19
# Epoch [59/300], Step [400/600], d_loss: 0.8821, g_loss: 2.7436, D(x): 0.74, D(G(z)): 0.22
# Epoch [59/300], Step [600/600], d_loss: 0.6746, g_loss: 2.3994, D(x): 0.86, D(G(z)): 0.28
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.4286, g_loss: 2.6930, D(x): 0.88, D(G(z)): 0.19
# Epoch [60/300], Step [400/600], d_loss: 0.5225, g_loss: 2.4738, D(x): 0.83, D(G(z)): 0.18
# Epoch [60/300], Step [600/600], d_loss: 0.5968, g_loss: 3.0022, D(x): 0.79, D(G(z)): 0.10
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.6536, g_loss: 2.0000, D(x): 0.80, D(G(z)): 0.19
# Epoch [61/300], Step [400/600], d_loss: 0.6289, g_loss: 2.0880, D(x): 0.75, D(G(z)): 0.14
# Epoch [61/300], Step [600/600], d_loss: 0.4465, g_loss: 2.6127, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.4565, g_loss: 3.5663, D(x): 0.80, D(G(z)): 0.08
# Epoch [62/300], Step [400/600], d_loss: 0.7733, g_loss: 2.6024, D(x): 0.74, D(G(z)): 0.15
# Epoch [62/300], Step [600/600], d_loss: 0.5410, g_loss: 2.0404, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.5018, g_loss: 2.9205, D(x): 0.81, D(G(z)): 0.10
# Epoch [63/300], Step [400/600], d_loss: 0.7362, g_loss: 3.0717, D(x): 0.75, D(G(z)): 0.16
# Epoch [63/300], Step [600/600], d_loss: 0.4231, g_loss: 3.4083, D(x): 0.89, D(G(z)): 0.16
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6708, g_loss: 2.5940, D(x): 0.74, D(G(z)): 0.14
# Epoch [64/300], Step [400/600], d_loss: 0.6432, g_loss: 2.5390, D(x): 0.79, D(G(z)): 0.18
# Epoch [64/300], Step [600/600], d_loss: 0.4563, g_loss: 2.5935, D(x): 0.84, D(G(z)): 0.16
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.4575, g_loss: 2.9927, D(x): 0.85, D(G(z)): 0.15
# Epoch [65/300], Step [400/600], d_loss: 0.6801, g_loss: 2.6616, D(x): 0.78, D(G(z)): 0.21
# Epoch [65/300], Step [600/600], d_loss: 0.5247, g_loss: 2.1551, D(x): 0.84, D(G(z)): 0.21
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.5630, g_loss: 2.6734, D(x): 0.81, D(G(z)): 0.18
# Epoch [66/300], Step [400/600], d_loss: 0.5703, g_loss: 2.3593, D(x): 0.80, D(G(z)): 0.17
# Epoch [66/300], Step [600/600], d_loss: 0.6112, g_loss: 2.1794, D(x): 0.84, D(G(z)): 0.25
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.6703, g_loss: 2.3688, D(x): 0.82, D(G(z)): 0.27
# Epoch [67/300], Step [400/600], d_loss: 0.6292, g_loss: 2.0872, D(x): 0.83, D(G(z)): 0.25
# Epoch [67/300], Step [600/600], d_loss: 0.6552, g_loss: 2.5170, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6738, g_loss: 2.2155, D(x): 0.81, D(G(z)): 0.24
# Epoch [68/300], Step [400/600], d_loss: 0.8546, g_loss: 1.5708, D(x): 0.78, D(G(z)): 0.29
# Epoch [68/300], Step [600/600], d_loss: 0.6931, g_loss: 2.3387, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6761, g_loss: 2.0883, D(x): 0.80, D(G(z)): 0.25
# Epoch [69/300], Step [400/600], d_loss: 0.3916, g_loss: 2.6100, D(x): 0.88, D(G(z)): 0.17
# Epoch [69/300], Step [600/600], d_loss: 0.6141, g_loss: 2.1489, D(x): 0.84, D(G(z)): 0.24
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.5860, g_loss: 2.6897, D(x): 0.75, D(G(z)): 0.14
# Epoch [70/300], Step [400/600], d_loss: 0.5909, g_loss: 2.4667, D(x): 0.81, D(G(z)): 0.21
# Epoch [70/300], Step [600/600], d_loss: 0.6249, g_loss: 1.8773, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6291, g_loss: 2.2819, D(x): 0.85, D(G(z)): 0.25
# Epoch [71/300], Step [400/600], d_loss: 0.7969, g_loss: 1.8253, D(x): 0.76, D(G(z)): 0.25
# Epoch [71/300], Step [600/600], d_loss: 0.6815, g_loss: 2.3416, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.5352, g_loss: 2.6724, D(x): 0.78, D(G(z)): 0.15
# Epoch [72/300], Step [400/600], d_loss: 0.5583, g_loss: 2.5148, D(x): 0.81, D(G(z)): 0.17
# Epoch [72/300], Step [600/600], d_loss: 0.6688, g_loss: 3.1058, D(x): 0.74, D(G(z)): 0.13
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6854, g_loss: 2.4796, D(x): 0.81, D(G(z)): 0.28
# Epoch [73/300], Step [400/600], d_loss: 0.5521, g_loss: 2.7269, D(x): 0.83, D(G(z)): 0.20
# Epoch [73/300], Step [600/600], d_loss: 0.6170, g_loss: 2.3356, D(x): 0.80, D(G(z)): 0.22
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.3964, g_loss: 2.5283, D(x): 0.93, D(G(z)): 0.23
# Epoch [74/300], Step [400/600], d_loss: 0.8548, g_loss: 1.8499, D(x): 0.78, D(G(z)): 0.29
# Epoch [74/300], Step [600/600], d_loss: 0.6531, g_loss: 2.4000, D(x): 0.71, D(G(z)): 0.10
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6110, g_loss: 2.8944, D(x): 0.81, D(G(z)): 0.23
# Epoch [75/300], Step [400/600], d_loss: 0.7012, g_loss: 2.0531, D(x): 0.88, D(G(z)): 0.33
# Epoch [75/300], Step [600/600], d_loss: 0.8867, g_loss: 1.7322, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.5828, g_loss: 2.6154, D(x): 0.79, D(G(z)): 0.18
# Epoch [76/300], Step [400/600], d_loss: 0.3903, g_loss: 2.9653, D(x): 0.85, D(G(z)): 0.12
# Epoch [76/300], Step [600/600], d_loss: 0.9580, g_loss: 1.9761, D(x): 0.64, D(G(z)): 0.16
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7991, g_loss: 2.5484, D(x): 0.75, D(G(z)): 0.21
# Epoch [77/300], Step [400/600], d_loss: 0.4811, g_loss: 2.5990, D(x): 0.87, D(G(z)): 0.20
# Epoch [77/300], Step [600/600], d_loss: 0.5903, g_loss: 2.2373, D(x): 0.85, D(G(z)): 0.25
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.8595, g_loss: 2.5414, D(x): 0.72, D(G(z)): 0.20
# Epoch [78/300], Step [400/600], d_loss: 0.5523, g_loss: 2.5194, D(x): 0.81, D(G(z)): 0.18
# Epoch [78/300], Step [600/600], d_loss: 0.6774, g_loss: 2.1073, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6419, g_loss: 2.7596, D(x): 0.79, D(G(z)): 0.16
# Epoch [79/300], Step [400/600], d_loss: 0.7197, g_loss: 2.7866, D(x): 0.72, D(G(z)): 0.13
# Epoch [79/300], Step [600/600], d_loss: 0.6840, g_loss: 2.4124, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.5905, g_loss: 2.5346, D(x): 0.82, D(G(z)): 0.21
# Epoch [80/300], Step [400/600], d_loss: 0.7022, g_loss: 2.0526, D(x): 0.70, D(G(z)): 0.10
# Epoch [80/300], Step [600/600], d_loss: 0.6888, g_loss: 2.2613, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.5904, g_loss: 2.0438, D(x): 0.84, D(G(z)): 0.26
# Epoch [81/300], Step [400/600], d_loss: 0.5289, g_loss: 2.2560, D(x): 0.78, D(G(z)): 0.17
# Epoch [81/300], Step [600/600], d_loss: 0.6644, g_loss: 1.9736, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.7492, g_loss: 2.3130, D(x): 0.76, D(G(z)): 0.22
# Epoch [82/300], Step [400/600], d_loss: 0.7037, g_loss: 2.3363, D(x): 0.73, D(G(z)): 0.16
# Epoch [82/300], Step [600/600], d_loss: 0.5133, g_loss: 2.6237, D(x): 0.88, D(G(z)): 0.24
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.6352, g_loss: 2.7923, D(x): 0.73, D(G(z)): 0.15
# Epoch [83/300], Step [400/600], d_loss: 0.7186, g_loss: 1.8675, D(x): 0.84, D(G(z)): 0.30
# Epoch [83/300], Step [600/600], d_loss: 0.8810, g_loss: 2.0225, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.7047, g_loss: 2.5445, D(x): 0.70, D(G(z)): 0.13
# Epoch [84/300], Step [400/600], d_loss: 0.5685, g_loss: 2.7271, D(x): 0.77, D(G(z)): 0.16
# Epoch [84/300], Step [600/600], d_loss: 0.6918, g_loss: 2.3167, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6506, g_loss: 2.6628, D(x): 0.73, D(G(z)): 0.13
# Epoch [85/300], Step [400/600], d_loss: 0.6590, g_loss: 2.2421, D(x): 0.79, D(G(z)): 0.21
# Epoch [85/300], Step [600/600], d_loss: 0.5422, g_loss: 1.8060, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.7567, g_loss: 2.2435, D(x): 0.80, D(G(z)): 0.27
# Epoch [86/300], Step [400/600], d_loss: 0.5441, g_loss: 2.3269, D(x): 0.78, D(G(z)): 0.13
# Epoch [86/300], Step [600/600], d_loss: 0.5770, g_loss: 2.2292, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.6756, g_loss: 2.4991, D(x): 0.84, D(G(z)): 0.26
# Epoch [87/300], Step [400/600], d_loss: 0.7325, g_loss: 3.0588, D(x): 0.70, D(G(z)): 0.12
# Epoch [87/300], Step [600/600], d_loss: 0.7765, g_loss: 2.4924, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.6755, g_loss: 1.8988, D(x): 0.79, D(G(z)): 0.24
# Epoch [88/300], Step [400/600], d_loss: 0.7953, g_loss: 1.6271, D(x): 0.72, D(G(z)): 0.21
# Epoch [88/300], Step [600/600], d_loss: 0.5461, g_loss: 2.7032, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.6393, g_loss: 2.9396, D(x): 0.78, D(G(z)): 0.18
# Epoch [89/300], Step [400/600], d_loss: 0.5468, g_loss: 2.6599, D(x): 0.84, D(G(z)): 0.22
# Epoch [89/300], Step [600/600], d_loss: 0.6473, g_loss: 2.5067, D(x): 0.86, D(G(z)): 0.29
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.6969, g_loss: 2.3276, D(x): 0.72, D(G(z)): 0.15
# Epoch [90/300], Step [400/600], d_loss: 0.5458, g_loss: 2.5824, D(x): 0.84, D(G(z)): 0.21
# Epoch [90/300], Step [600/600], d_loss: 0.5082, g_loss: 2.3863, D(x): 0.90, D(G(z)): 0.26
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.6654, g_loss: 3.2502, D(x): 0.78, D(G(z)): 0.18
# Epoch [91/300], Step [400/600], d_loss: 0.9367, g_loss: 2.4474, D(x): 0.65, D(G(z)): 0.15
# Epoch [91/300], Step [600/600], d_loss: 0.6840, g_loss: 2.8156, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.6468, g_loss: 2.6534, D(x): 0.83, D(G(z)): 0.26
# Epoch [92/300], Step [400/600], d_loss: 0.6710, g_loss: 3.0406, D(x): 0.71, D(G(z)): 0.08
# Epoch [92/300], Step [600/600], d_loss: 0.6170, g_loss: 2.0209, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.5481, g_loss: 2.5428, D(x): 0.87, D(G(z)): 0.22
# Epoch [93/300], Step [400/600], d_loss: 0.9268, g_loss: 2.1102, D(x): 0.71, D(G(z)): 0.25
# Epoch [93/300], Step [600/600], d_loss: 0.8432, g_loss: 1.8737, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.6731, g_loss: 1.6714, D(x): 0.81, D(G(z)): 0.23
# Epoch [94/300], Step [400/600], d_loss: 0.7271, g_loss: 2.4282, D(x): 0.81, D(G(z)): 0.26
# Epoch [94/300], Step [600/600], d_loss: 0.5839, g_loss: 2.4772, D(x): 0.85, D(G(z)): 0.27
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.8480, g_loss: 1.6145, D(x): 0.69, D(G(z)): 0.20
# Epoch [95/300], Step [400/600], d_loss: 0.8812, g_loss: 1.8122, D(x): 0.74, D(G(z)): 0.25
# Epoch [95/300], Step [600/600], d_loss: 0.7758, g_loss: 1.5522, D(x): 0.83, D(G(z)): 0.31
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.8009, g_loss: 1.2783, D(x): 0.82, D(G(z)): 0.33
# Epoch [96/300], Step [400/600], d_loss: 0.3944, g_loss: 2.0709, D(x): 0.87, D(G(z)): 0.16
# Epoch [96/300], Step [600/600], d_loss: 0.6130, g_loss: 1.9423, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7237, g_loss: 2.5352, D(x): 0.69, D(G(z)): 0.15
# Epoch [97/300], Step [400/600], d_loss: 0.8432, g_loss: 1.5065, D(x): 0.81, D(G(z)): 0.35
# Epoch [97/300], Step [600/600], d_loss: 0.9610, g_loss: 1.6828, D(x): 0.64, D(G(z)): 0.20
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.7833, g_loss: 1.5543, D(x): 0.71, D(G(z)): 0.22
# Epoch [98/300], Step [400/600], d_loss: 0.6498, g_loss: 2.0683, D(x): 0.81, D(G(z)): 0.26
# Epoch [98/300], Step [600/600], d_loss: 0.7693, g_loss: 1.7692, D(x): 0.83, D(G(z)): 0.34
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.7366, g_loss: 1.9214, D(x): 0.80, D(G(z)): 0.26
# Epoch [99/300], Step [400/600], d_loss: 0.7246, g_loss: 1.9839, D(x): 0.73, D(G(z)): 0.19
# Epoch [99/300], Step [600/600], d_loss: 0.7672, g_loss: 2.3260, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.6119, g_loss: 1.9362, D(x): 0.80, D(G(z)): 0.20
# Epoch [100/300], Step [400/600], d_loss: 0.8206, g_loss: 1.7073, D(x): 0.79, D(G(z)): 0.30
# Epoch [100/300], Step [600/600], d_loss: 0.9834, g_loss: 1.8901, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.8259, g_loss: 1.8806, D(x): 0.83, D(G(z)): 0.34
# Epoch [101/300], Step [400/600], d_loss: 0.6853, g_loss: 2.3855, D(x): 0.73, D(G(z)): 0.17
# Epoch [101/300], Step [600/600], d_loss: 0.8015, g_loss: 1.4092, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.7518, g_loss: 1.8739, D(x): 0.77, D(G(z)): 0.28
# Epoch [102/300], Step [400/600], d_loss: 0.7075, g_loss: 1.7603, D(x): 0.73, D(G(z)): 0.18
# Epoch [102/300], Step [600/600], d_loss: 0.8562, g_loss: 1.4797, D(x): 0.84, D(G(z)): 0.35
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7379, g_loss: 2.1271, D(x): 0.75, D(G(z)): 0.22
# Epoch [103/300], Step [400/600], d_loss: 0.8177, g_loss: 1.9631, D(x): 0.77, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.6323, g_loss: 2.2850, D(x): 0.76, D(G(z)): 0.19
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.7169, g_loss: 1.9828, D(x): 0.82, D(G(z)): 0.29
# Epoch [104/300], Step [400/600], d_loss: 0.7702, g_loss: 2.1150, D(x): 0.76, D(G(z)): 0.24
# Epoch [104/300], Step [600/600], d_loss: 0.8752, g_loss: 1.8536, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.8253, g_loss: 2.2518, D(x): 0.68, D(G(z)): 0.13
# Epoch [105/300], Step [400/600], d_loss: 0.6499, g_loss: 2.2319, D(x): 0.78, D(G(z)): 0.22
# Epoch [105/300], Step [600/600], d_loss: 0.6950, g_loss: 2.2920, D(x): 0.76, D(G(z)): 0.19
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.7691, g_loss: 1.3192, D(x): 0.77, D(G(z)): 0.30
# Epoch [106/300], Step [400/600], d_loss: 0.6838, g_loss: 2.0550, D(x): 0.72, D(G(z)): 0.19
# Epoch [106/300], Step [600/600], d_loss: 0.8814, g_loss: 1.3578, D(x): 0.81, D(G(z)): 0.40
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8805, g_loss: 1.7969, D(x): 0.77, D(G(z)): 0.31
# Epoch [107/300], Step [400/600], d_loss: 0.8038, g_loss: 2.0082, D(x): 0.72, D(G(z)): 0.25
# Epoch [107/300], Step [600/600], d_loss: 0.6363, g_loss: 2.1830, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.6977, g_loss: 2.0607, D(x): 0.78, D(G(z)): 0.23
# Epoch [108/300], Step [400/600], d_loss: 0.8068, g_loss: 1.8726, D(x): 0.80, D(G(z)): 0.32
# Epoch [108/300], Step [600/600], d_loss: 0.7227, g_loss: 1.4421, D(x): 0.81, D(G(z)): 0.28
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.8288, g_loss: 1.7502, D(x): 0.70, D(G(z)): 0.24
# Epoch [109/300], Step [400/600], d_loss: 1.0539, g_loss: 1.7536, D(x): 0.75, D(G(z)): 0.37
# Epoch [109/300], Step [600/600], d_loss: 0.9006, g_loss: 1.4856, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.6829, g_loss: 1.6811, D(x): 0.71, D(G(z)): 0.18
# Epoch [110/300], Step [400/600], d_loss: 1.0260, g_loss: 1.5960, D(x): 0.71, D(G(z)): 0.32
# Epoch [110/300], Step [600/600], d_loss: 0.8381, g_loss: 2.1932, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 1.2294, g_loss: 1.7118, D(x): 0.68, D(G(z)): 0.37
# Epoch [111/300], Step [400/600], d_loss: 0.9455, g_loss: 1.9775, D(x): 0.65, D(G(z)): 0.18
# Epoch [111/300], Step [600/600], d_loss: 0.5419, g_loss: 1.7700, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.7784, g_loss: 1.8688, D(x): 0.75, D(G(z)): 0.23
# Epoch [112/300], Step [400/600], d_loss: 0.7300, g_loss: 2.8904, D(x): 0.70, D(G(z)): 0.12
# Epoch [112/300], Step [600/600], d_loss: 0.9041, g_loss: 2.4077, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9107, g_loss: 1.8335, D(x): 0.83, D(G(z)): 0.39
# Epoch [113/300], Step [400/600], d_loss: 0.7468, g_loss: 1.7769, D(x): 0.75, D(G(z)): 0.24
# Epoch [113/300], Step [600/600], d_loss: 0.6451, g_loss: 1.9619, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 1.0347, g_loss: 1.6362, D(x): 0.69, D(G(z)): 0.33
# Epoch [114/300], Step [400/600], d_loss: 0.8063, g_loss: 1.7983, D(x): 0.73, D(G(z)): 0.27
# Epoch [114/300], Step [600/600], d_loss: 0.7890, g_loss: 1.7701, D(x): 0.75, D(G(z)): 0.22
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.7688, g_loss: 1.5952, D(x): 0.80, D(G(z)): 0.32
# Epoch [115/300], Step [400/600], d_loss: 0.8952, g_loss: 1.6281, D(x): 0.70, D(G(z)): 0.26
# Epoch [115/300], Step [600/600], d_loss: 0.9326, g_loss: 2.2831, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.5986, g_loss: 1.6167, D(x): 0.84, D(G(z)): 0.27
# Epoch [116/300], Step [400/600], d_loss: 0.8407, g_loss: 2.0402, D(x): 0.72, D(G(z)): 0.27
# Epoch [116/300], Step [600/600], d_loss: 0.7804, g_loss: 2.1676, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.8973, g_loss: 1.4982, D(x): 0.83, D(G(z)): 0.41
# Epoch [117/300], Step [400/600], d_loss: 0.9528, g_loss: 1.4136, D(x): 0.72, D(G(z)): 0.32
# Epoch [117/300], Step [600/600], d_loss: 1.0685, g_loss: 1.8278, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8695, g_loss: 1.8749, D(x): 0.66, D(G(z)): 0.21
# Epoch [118/300], Step [400/600], d_loss: 0.8780, g_loss: 2.0641, D(x): 0.71, D(G(z)): 0.28
# Epoch [118/300], Step [600/600], d_loss: 0.8928, g_loss: 2.0731, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.7629, g_loss: 2.1918, D(x): 0.82, D(G(z)): 0.33
# Epoch [119/300], Step [400/600], d_loss: 1.0712, g_loss: 1.3130, D(x): 0.66, D(G(z)): 0.30
# Epoch [119/300], Step [600/600], d_loss: 0.5095, g_loss: 2.2069, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.8046, g_loss: 1.6746, D(x): 0.73, D(G(z)): 0.24
# Epoch [120/300], Step [400/600], d_loss: 0.8791, g_loss: 1.8153, D(x): 0.67, D(G(z)): 0.20
# Epoch [120/300], Step [600/600], d_loss: 0.8714, g_loss: 1.7412, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.8558, g_loss: 1.7314, D(x): 0.78, D(G(z)): 0.34
# Epoch [121/300], Step [400/600], d_loss: 1.0307, g_loss: 1.4408, D(x): 0.70, D(G(z)): 0.30
# Epoch [121/300], Step [600/600], d_loss: 0.8731, g_loss: 1.8386, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8310, g_loss: 1.7290, D(x): 0.68, D(G(z)): 0.21
# Epoch [122/300], Step [400/600], d_loss: 0.9292, g_loss: 1.7460, D(x): 0.78, D(G(z)): 0.39
# Epoch [122/300], Step [600/600], d_loss: 0.5856, g_loss: 2.3179, D(x): 0.77, D(G(z)): 0.18
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.9007, g_loss: 2.0603, D(x): 0.76, D(G(z)): 0.33
# Epoch [123/300], Step [400/600], d_loss: 0.8613, g_loss: 2.0963, D(x): 0.76, D(G(z)): 0.28
# Epoch [123/300], Step [600/600], d_loss: 0.7942, g_loss: 1.7430, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.9770, g_loss: 2.4653, D(x): 0.67, D(G(z)): 0.24
# Epoch [124/300], Step [400/600], d_loss: 0.8297, g_loss: 1.8268, D(x): 0.71, D(G(z)): 0.24
# Epoch [124/300], Step [600/600], d_loss: 0.9161, g_loss: 1.6193, D(x): 0.68, D(G(z)): 0.22
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.8627, g_loss: 1.7734, D(x): 0.71, D(G(z)): 0.27
# Epoch [125/300], Step [400/600], d_loss: 0.9569, g_loss: 1.6633, D(x): 0.75, D(G(z)): 0.35
# Epoch [125/300], Step [600/600], d_loss: 0.8722, g_loss: 1.7957, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.9290, g_loss: 1.5590, D(x): 0.67, D(G(z)): 0.24
# Epoch [126/300], Step [400/600], d_loss: 0.7133, g_loss: 2.0420, D(x): 0.83, D(G(z)): 0.29
# Epoch [126/300], Step [600/600], d_loss: 1.0047, g_loss: 1.5078, D(x): 0.80, D(G(z)): 0.42
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.7415, g_loss: 2.0332, D(x): 0.73, D(G(z)): 0.22
# Epoch [127/300], Step [400/600], d_loss: 0.9484, g_loss: 1.7044, D(x): 0.70, D(G(z)): 0.29
# Epoch [127/300], Step [600/600], d_loss: 0.9784, g_loss: 1.7184, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.7937, g_loss: 2.0896, D(x): 0.77, D(G(z)): 0.26
# Epoch [128/300], Step [400/600], d_loss: 0.9133, g_loss: 1.6386, D(x): 0.73, D(G(z)): 0.29
# Epoch [128/300], Step [600/600], d_loss: 0.9173, g_loss: 1.4454, D(x): 0.76, D(G(z)): 0.36
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 1.0608, g_loss: 1.7056, D(x): 0.74, D(G(z)): 0.34
# Epoch [129/300], Step [400/600], d_loss: 0.8616, g_loss: 1.6363, D(x): 0.80, D(G(z)): 0.37
# Epoch [129/300], Step [600/600], d_loss: 0.9047, g_loss: 1.6641, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.6813, g_loss: 2.3475, D(x): 0.76, D(G(z)): 0.23
# Epoch [130/300], Step [400/600], d_loss: 0.6452, g_loss: 1.6867, D(x): 0.78, D(G(z)): 0.25
# Epoch [130/300], Step [600/600], d_loss: 0.7958, g_loss: 2.2664, D(x): 0.72, D(G(z)): 0.20
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.9508, g_loss: 1.7360, D(x): 0.76, D(G(z)): 0.34
# Epoch [131/300], Step [400/600], d_loss: 0.8695, g_loss: 1.7169, D(x): 0.76, D(G(z)): 0.33
# Epoch [131/300], Step [600/600], d_loss: 0.8253, g_loss: 1.3432, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.8135, g_loss: 2.0787, D(x): 0.71, D(G(z)): 0.24
# Epoch [132/300], Step [400/600], d_loss: 1.0301, g_loss: 1.7875, D(x): 0.66, D(G(z)): 0.31
# Epoch [132/300], Step [600/600], d_loss: 0.8912, g_loss: 1.8270, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8991, g_loss: 2.1707, D(x): 0.68, D(G(z)): 0.23
# Epoch [133/300], Step [400/600], d_loss: 0.8767, g_loss: 2.1074, D(x): 0.74, D(G(z)): 0.28
# Epoch [133/300], Step [600/600], d_loss: 1.0662, g_loss: 1.9491, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 1.0160, g_loss: 1.0061, D(x): 0.70, D(G(z)): 0.35
# Epoch [134/300], Step [400/600], d_loss: 0.8086, g_loss: 1.8621, D(x): 0.70, D(G(z)): 0.22
# Epoch [134/300], Step [600/600], d_loss: 0.8004, g_loss: 1.5950, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 1.0101, g_loss: 2.0519, D(x): 0.64, D(G(z)): 0.23
# Epoch [135/300], Step [400/600], d_loss: 0.8018, g_loss: 1.7903, D(x): 0.79, D(G(z)): 0.34
# Epoch [135/300], Step [600/600], d_loss: 0.8983, g_loss: 1.7975, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 1.1307, g_loss: 1.8902, D(x): 0.63, D(G(z)): 0.27
# Epoch [136/300], Step [400/600], d_loss: 0.9531, g_loss: 1.2048, D(x): 0.69, D(G(z)): 0.31
# Epoch [136/300], Step [600/600], d_loss: 0.7639, g_loss: 1.8264, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.7966, g_loss: 1.8619, D(x): 0.75, D(G(z)): 0.28
# Epoch [137/300], Step [400/600], d_loss: 0.7921, g_loss: 2.0846, D(x): 0.69, D(G(z)): 0.20
# Epoch [137/300], Step [600/600], d_loss: 0.9884, g_loss: 1.6881, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.7705, g_loss: 2.1684, D(x): 0.75, D(G(z)): 0.23
# Epoch [138/300], Step [400/600], d_loss: 0.8514, g_loss: 1.4577, D(x): 0.76, D(G(z)): 0.33
# Epoch [138/300], Step [600/600], d_loss: 0.9767, g_loss: 1.7366, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9671, g_loss: 1.6999, D(x): 0.68, D(G(z)): 0.31
# Epoch [139/300], Step [400/600], d_loss: 0.8356, g_loss: 2.1296, D(x): 0.80, D(G(z)): 0.34
# Epoch [139/300], Step [600/600], d_loss: 0.9291, g_loss: 1.8009, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.8979, g_loss: 1.8537, D(x): 0.67, D(G(z)): 0.22
# Epoch [140/300], Step [400/600], d_loss: 0.9135, g_loss: 1.8962, D(x): 0.66, D(G(z)): 0.20
# Epoch [140/300], Step [600/600], d_loss: 0.8613, g_loss: 1.5705, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.8199, g_loss: 1.3548, D(x): 0.78, D(G(z)): 0.29
# Epoch [141/300], Step [400/600], d_loss: 0.9373, g_loss: 1.7024, D(x): 0.64, D(G(z)): 0.23
# Epoch [141/300], Step [600/600], d_loss: 0.9940, g_loss: 1.5932, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.9378, g_loss: 1.6661, D(x): 0.70, D(G(z)): 0.27
# Epoch [142/300], Step [400/600], d_loss: 0.7577, g_loss: 1.8702, D(x): 0.76, D(G(z)): 0.26
# Epoch [142/300], Step [600/600], d_loss: 0.9323, g_loss: 1.5304, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.8101, g_loss: 1.7215, D(x): 0.71, D(G(z)): 0.27
# Epoch [143/300], Step [400/600], d_loss: 0.7250, g_loss: 1.8380, D(x): 0.73, D(G(z)): 0.24
# Epoch [143/300], Step [600/600], d_loss: 0.8359, g_loss: 1.8040, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.7284, g_loss: 1.6920, D(x): 0.73, D(G(z)): 0.21
# Epoch [144/300], Step [400/600], d_loss: 0.8425, g_loss: 1.6093, D(x): 0.72, D(G(z)): 0.25
# Epoch [144/300], Step [600/600], d_loss: 0.8716, g_loss: 1.6766, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9332, g_loss: 1.2306, D(x): 0.82, D(G(z)): 0.41
# Epoch [145/300], Step [400/600], d_loss: 0.9134, g_loss: 1.6271, D(x): 0.71, D(G(z)): 0.31
# Epoch [145/300], Step [600/600], d_loss: 0.8141, g_loss: 1.7902, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.9636, g_loss: 1.2598, D(x): 0.66, D(G(z)): 0.22
# Epoch [146/300], Step [400/600], d_loss: 0.9432, g_loss: 1.9591, D(x): 0.64, D(G(z)): 0.21
# Epoch [146/300], Step [600/600], d_loss: 0.7733, g_loss: 2.0143, D(x): 0.75, D(G(z)): 0.28
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.7984, g_loss: 1.6188, D(x): 0.76, D(G(z)): 0.30
# Epoch [147/300], Step [400/600], d_loss: 1.0564, g_loss: 1.5113, D(x): 0.64, D(G(z)): 0.29
# Epoch [147/300], Step [600/600], d_loss: 0.6984, g_loss: 1.6454, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.9209, g_loss: 1.7916, D(x): 0.71, D(G(z)): 0.29
# Epoch [148/300], Step [400/600], d_loss: 0.8331, g_loss: 1.4796, D(x): 0.75, D(G(z)): 0.30
# Epoch [148/300], Step [600/600], d_loss: 0.8954, g_loss: 1.8508, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 1.0144, g_loss: 1.5506, D(x): 0.59, D(G(z)): 0.21
# Epoch [149/300], Step [400/600], d_loss: 1.0056, g_loss: 1.3627, D(x): 0.76, D(G(z)): 0.39
# Epoch [149/300], Step [600/600], d_loss: 0.9088, g_loss: 1.3726, D(x): 0.79, D(G(z)): 0.38
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0982, g_loss: 1.7052, D(x): 0.67, D(G(z)): 0.32
# Epoch [150/300], Step [400/600], d_loss: 0.9270, g_loss: 1.2373, D(x): 0.74, D(G(z)): 0.38
# Epoch [150/300], Step [600/600], d_loss: 0.9054, g_loss: 1.4543, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9568, g_loss: 1.7728, D(x): 0.69, D(G(z)): 0.30
# Epoch [151/300], Step [400/600], d_loss: 0.9207, g_loss: 1.6825, D(x): 0.71, D(G(z)): 0.27
# Epoch [151/300], Step [600/600], d_loss: 0.7538, g_loss: 2.1800, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.7631, g_loss: 1.9620, D(x): 0.78, D(G(z)): 0.28
# Epoch [152/300], Step [400/600], d_loss: 0.8243, g_loss: 1.6503, D(x): 0.68, D(G(z)): 0.18
# Epoch [152/300], Step [600/600], d_loss: 0.6397, g_loss: 1.9199, D(x): 0.77, D(G(z)): 0.24
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.9997, g_loss: 2.0253, D(x): 0.66, D(G(z)): 0.26
# Epoch [153/300], Step [400/600], d_loss: 1.1234, g_loss: 1.8756, D(x): 0.59, D(G(z)): 0.27
# Epoch [153/300], Step [600/600], d_loss: 0.9391, g_loss: 1.5846, D(x): 0.75, D(G(z)): 0.36
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.8147, g_loss: 1.6991, D(x): 0.70, D(G(z)): 0.25
# Epoch [154/300], Step [400/600], d_loss: 0.8130, g_loss: 1.3347, D(x): 0.81, D(G(z)): 0.37
# Epoch [154/300], Step [600/600], d_loss: 0.8837, g_loss: 1.6693, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.8892, g_loss: 1.8055, D(x): 0.79, D(G(z)): 0.38
# Epoch [155/300], Step [400/600], d_loss: 0.9653, g_loss: 1.9604, D(x): 0.60, D(G(z)): 0.19
# Epoch [155/300], Step [600/600], d_loss: 0.9188, g_loss: 1.6793, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.7581, g_loss: 1.5819, D(x): 0.71, D(G(z)): 0.25
# Epoch [156/300], Step [400/600], d_loss: 0.7825, g_loss: 1.8962, D(x): 0.68, D(G(z)): 0.19
# Epoch [156/300], Step [600/600], d_loss: 1.0061, g_loss: 1.2937, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.9394, g_loss: 1.3666, D(x): 0.71, D(G(z)): 0.29
# Epoch [157/300], Step [400/600], d_loss: 0.9174, g_loss: 1.2895, D(x): 0.72, D(G(z)): 0.32
# Epoch [157/300], Step [600/600], d_loss: 0.8638, g_loss: 1.5209, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.7387, g_loss: 2.0468, D(x): 0.74, D(G(z)): 0.21
# Epoch [158/300], Step [400/600], d_loss: 0.9242, g_loss: 1.9585, D(x): 0.70, D(G(z)): 0.25
# Epoch [158/300], Step [600/600], d_loss: 0.9698, g_loss: 1.6358, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.7054, g_loss: 1.7149, D(x): 0.76, D(G(z)): 0.26
# Epoch [159/300], Step [400/600], d_loss: 1.0027, g_loss: 1.5930, D(x): 0.71, D(G(z)): 0.32
# Epoch [159/300], Step [600/600], d_loss: 1.0810, g_loss: 1.5342, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.8601, g_loss: 1.9817, D(x): 0.70, D(G(z)): 0.26
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.9290, g_loss: 1.3976, D(x): 0.78, D(G(z)): 0.40
# Epoch [247/300], Step [600/600], d_loss: 0.9524, g_loss: 1.9138, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 1.0442, g_loss: 1.2740, D(x): 0.74, D(G(z)): 0.42
# Epoch [248/300], Step [400/600], d_loss: 0.8442, g_loss: 1.6721, D(x): 0.77, D(G(z)): 0.33
# Epoch [248/300], Step [600/600], d_loss: 0.9674, g_loss: 1.6731, D(x): 0.60, D(G(z)): 0.19
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.8727, g_loss: 1.4186, D(x): 0.74, D(G(z)): 0.32
# Epoch [249/300], Step [400/600], d_loss: 0.8720, g_loss: 1.4763, D(x): 0.68, D(G(z)): 0.26
# Epoch [249/300], Step [600/600], d_loss: 0.9596, g_loss: 1.4289, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.8444, g_loss: 1.8929, D(x): 0.67, D(G(z)): 0.23
# Epoch [250/300], Step [400/600], d_loss: 0.8878, g_loss: 1.4680, D(x): 0.78, D(G(z)): 0.38
# Epoch [250/300], Step [600/600], d_loss: 1.0250, g_loss: 1.5095, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.8704, g_loss: 1.3608, D(x): 0.70, D(G(z)): 0.31
# Epoch [251/300], Step [400/600], d_loss: 0.7380, g_loss: 1.8805, D(x): 0.72, D(G(z)): 0.24
# Epoch [251/300], Step [600/600], d_loss: 0.8793, g_loss: 1.3898, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9643, g_loss: 1.6068, D(x): 0.71, D(G(z)): 0.31
# Epoch [252/300], Step [400/600], d_loss: 0.8390, g_loss: 1.5423, D(x): 0.73, D(G(z)): 0.30
# Epoch [252/300], Step [600/600], d_loss: 1.0326, g_loss: 1.6783, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.9551, g_loss: 1.5287, D(x): 0.68, D(G(z)): 0.30
# Epoch [253/300], Step [400/600], d_loss: 1.0353, g_loss: 1.7270, D(x): 0.67, D(G(z)): 0.32
# Epoch [253/300], Step [600/600], d_loss: 0.8167, g_loss: 1.5285, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.8267, g_loss: 1.7059, D(x): 0.77, D(G(z)): 0.35
# Epoch [254/300], Step [400/600], d_loss: 0.8478, g_loss: 1.1357, D(x): 0.74, D(G(z)): 0.32
# Epoch [254/300], Step [600/600], d_loss: 0.8541, g_loss: 1.8847, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.7247, g_loss: 1.6859, D(x): 0.74, D(G(z)): 0.23
# Epoch [255/300], Step [400/600], d_loss: 1.0818, g_loss: 1.3059, D(x): 0.72, D(G(z)): 0.41
# Epoch [255/300], Step [600/600], d_loss: 0.8878, g_loss: 1.4153, D(x): 0.62, D(G(z)): 0.21
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9709, g_loss: 1.8288, D(x): 0.69, D(G(z)): 0.31
# Epoch [256/300], Step [400/600], d_loss: 0.8903, g_loss: 1.7486, D(x): 0.66, D(G(z)): 0.25
# Epoch [256/300], Step [600/600], d_loss: 1.0426, g_loss: 1.5041, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9416, g_loss: 1.4688, D(x): 0.71, D(G(z)): 0.34
# Epoch [257/300], Step [400/600], d_loss: 0.8782, g_loss: 1.6858, D(x): 0.68, D(G(z)): 0.27
# Epoch [257/300], Step [600/600], d_loss: 0.9700, g_loss: 1.7535, D(x): 0.75, D(G(z)): 0.38
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.9597, g_loss: 1.4998, D(x): 0.69, D(G(z)): 0.32
# Epoch [258/300], Step [400/600], d_loss: 0.8102, g_loss: 1.5143, D(x): 0.73, D(G(z)): 0.27
# Epoch [258/300], Step [600/600], d_loss: 0.9861, g_loss: 1.7336, D(x): 0.61, D(G(z)): 0.23
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.8290, g_loss: 1.7727, D(x): 0.75, D(G(z)): 0.31
# Epoch [259/300], Step [400/600], d_loss: 0.7951, g_loss: 1.5120, D(x): 0.71, D(G(z)): 0.23
# Epoch [259/300], Step [600/600], d_loss: 0.8755, g_loss: 1.6813, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 1.0172, g_loss: 1.2313, D(x): 0.67, D(G(z)): 0.34
# Epoch [260/300], Step [400/600], d_loss: 0.9625, g_loss: 1.6739, D(x): 0.75, D(G(z)): 0.37
# Epoch [260/300], Step [600/600], d_loss: 0.8528, g_loss: 1.7083, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.8672, g_loss: 1.6050, D(x): 0.79, D(G(z)): 0.38
# Epoch [261/300], Step [400/600], d_loss: 0.9892, g_loss: 1.3641, D(x): 0.72, D(G(z)): 0.37
# Epoch [261/300], Step [600/600], d_loss: 1.0059, g_loss: 1.6213, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.8524, g_loss: 1.9002, D(x): 0.68, D(G(z)): 0.24
# Epoch [262/300], Step [400/600], d_loss: 0.9923, g_loss: 1.7087, D(x): 0.64, D(G(z)): 0.30
# Epoch [262/300], Step [600/600], d_loss: 1.0355, g_loss: 1.2939, D(x): 0.77, D(G(z)): 0.41
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9069, g_loss: 1.5271, D(x): 0.71, D(G(z)): 0.32
# Epoch [263/300], Step [400/600], d_loss: 0.9454, g_loss: 2.0225, D(x): 0.62, D(G(z)): 0.22
# Epoch [263/300], Step [600/600], d_loss: 0.9404, g_loss: 1.6505, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.8464, g_loss: 1.6124, D(x): 0.66, D(G(z)): 0.22
# Epoch [264/300], Step [400/600], d_loss: 1.0594, g_loss: 1.4053, D(x): 0.69, D(G(z)): 0.34
# Epoch [264/300], Step [600/600], d_loss: 0.8536, g_loss: 1.8748, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 1.0826, g_loss: 1.8291, D(x): 0.56, D(G(z)): 0.21
# Epoch [265/300], Step [400/600], d_loss: 0.9940, g_loss: 1.6490, D(x): 0.63, D(G(z)): 0.26
# Epoch [265/300], Step [600/600], d_loss: 0.9798, g_loss: 1.9567, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.8915, g_loss: 1.5468, D(x): 0.69, D(G(z)): 0.27
# Epoch [266/300], Step [400/600], d_loss: 0.9177, g_loss: 1.4033, D(x): 0.70, D(G(z)): 0.30
# Epoch [266/300], Step [600/600], d_loss: 0.9038, g_loss: 1.7368, D(x): 0.62, D(G(z)): 0.19
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.7571, g_loss: 1.5584, D(x): 0.74, D(G(z)): 0.28
# Epoch [267/300], Step [400/600], d_loss: 0.9580, g_loss: 1.7666, D(x): 0.66, D(G(z)): 0.28
# Epoch [267/300], Step [600/600], d_loss: 0.8669, g_loss: 1.4240, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8939, g_loss: 1.4262, D(x): 0.75, D(G(z)): 0.36
# Epoch [268/300], Step [400/600], d_loss: 1.0336, g_loss: 1.5900, D(x): 0.60, D(G(z)): 0.28
# Epoch [268/300], Step [600/600], d_loss: 0.7958, g_loss: 1.5950, D(x): 0.69, D(G(z)): 0.22
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.9725, g_loss: 1.1566, D(x): 0.71, D(G(z)): 0.35
# Epoch [269/300], Step [400/600], d_loss: 0.8285, g_loss: 1.4160, D(x): 0.75, D(G(z)): 0.31
# Epoch [269/300], Step [600/600], d_loss: 1.0898, g_loss: 2.1502, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9514, g_loss: 1.2060, D(x): 0.71, D(G(z)): 0.34
# Epoch [270/300], Step [400/600], d_loss: 0.8948, g_loss: 1.3329, D(x): 0.75, D(G(z)): 0.34
# Epoch [270/300], Step [600/600], d_loss: 0.7957, g_loss: 1.5758, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9461, g_loss: 1.1687, D(x): 0.69, D(G(z)): 0.30
# Epoch [271/300], Step [400/600], d_loss: 0.9246, g_loss: 1.8130, D(x): 0.62, D(G(z)): 0.24
# Epoch [271/300], Step [600/600], d_loss: 0.9216, g_loss: 1.7330, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9580, g_loss: 1.5156, D(x): 0.68, D(G(z)): 0.29
# Epoch [272/300], Step [400/600], d_loss: 1.0889, g_loss: 1.4829, D(x): 0.65, D(G(z)): 0.30
# Epoch [272/300], Step [600/600], d_loss: 1.0726, g_loss: 1.2176, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 1.0368, g_loss: 1.3440, D(x): 0.75, D(G(z)): 0.41
# Epoch [273/300], Step [400/600], d_loss: 1.0027, g_loss: 2.2010, D(x): 0.66, D(G(z)): 0.28
# Epoch [273/300], Step [600/600], d_loss: 0.8878, g_loss: 1.4123, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.8602, g_loss: 1.3667, D(x): 0.72, D(G(z)): 0.31
# Epoch [274/300], Step [400/600], d_loss: 0.9637, g_loss: 1.6519, D(x): 0.67, D(G(z)): 0.26
# Epoch [274/300], Step [600/600], d_loss: 0.9331, g_loss: 1.7254, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.8706, g_loss: 1.6402, D(x): 0.75, D(G(z)): 0.33
# Epoch [275/300], Step [400/600], d_loss: 0.8600, g_loss: 1.5782, D(x): 0.73, D(G(z)): 0.30
# Epoch [275/300], Step [600/600], d_loss: 0.9829, g_loss: 1.9740, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 1.0067, g_loss: 1.8539, D(x): 0.70, D(G(z)): 0.30
# Epoch [276/300], Step [400/600], d_loss: 0.9078, g_loss: 1.8549, D(x): 0.75, D(G(z)): 0.34
# Epoch [276/300], Step [600/600], d_loss: 0.9665, g_loss: 1.2753, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.8819, g_loss: 1.4329, D(x): 0.74, D(G(z)): 0.30
# Epoch [277/300], Step [400/600], d_loss: 0.9990, g_loss: 1.6939, D(x): 0.71, D(G(z)): 0.38
# Epoch [277/300], Step [600/600], d_loss: 0.8715, g_loss: 1.5268, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.8487, g_loss: 1.4598, D(x): 0.68, D(G(z)): 0.24
# Epoch [278/300], Step [400/600], d_loss: 0.9914, g_loss: 1.4550, D(x): 0.61, D(G(z)): 0.26
# Epoch [278/300], Step [600/600], d_loss: 0.9698, g_loss: 1.4699, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.8064, g_loss: 1.6034, D(x): 0.66, D(G(z)): 0.21
# Epoch [279/300], Step [400/600], d_loss: 1.0650, g_loss: 1.6566, D(x): 0.63, D(G(z)): 0.30
# Epoch [279/300], Step [600/600], d_loss: 0.7862, g_loss: 1.4106, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.7823, g_loss: 1.5681, D(x): 0.82, D(G(z)): 0.37
# Epoch [280/300], Step [400/600], d_loss: 0.9284, g_loss: 1.7591, D(x): 0.66, D(G(z)): 0.28
# Epoch [280/300], Step [600/600], d_loss: 0.8308, g_loss: 1.7989, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8097, g_loss: 1.7249, D(x): 0.70, D(G(z)): 0.25
# Epoch [281/300], Step [400/600], d_loss: 1.0188, g_loss: 1.6092, D(x): 0.67, D(G(z)): 0.33
# Epoch [281/300], Step [600/600], d_loss: 0.9732, g_loss: 1.6398, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.8050, g_loss: 1.5161, D(x): 0.79, D(G(z)): 0.33
# Epoch [282/300], Step [400/600], d_loss: 0.9433, g_loss: 1.6034, D(x): 0.71, D(G(z)): 0.32
# Epoch [282/300], Step [600/600], d_loss: 0.9261, g_loss: 1.6278, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.8795, g_loss: 1.6487, D(x): 0.66, D(G(z)): 0.24
# Epoch [283/300], Step [400/600], d_loss: 0.7465, g_loss: 1.5572, D(x): 0.74, D(G(z)): 0.25
# Epoch [283/300], Step [600/600], d_loss: 0.9092, g_loss: 1.6186, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.8567, g_loss: 1.4793, D(x): 0.67, D(G(z)): 0.23
# Epoch [284/300], Step [400/600], d_loss: 0.9383, g_loss: 1.4158, D(x): 0.68, D(G(z)): 0.30
# Epoch [284/300], Step [600/600], d_loss: 0.8740, g_loss: 1.4699, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.7922, g_loss: 2.0319, D(x): 0.70, D(G(z)): 0.25
# Epoch [285/300], Step [400/600], d_loss: 0.8944, g_loss: 1.6802, D(x): 0.69, D(G(z)): 0.29
# Epoch [285/300], Step [600/600], d_loss: 0.8843, g_loss: 1.4224, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.7800, g_loss: 1.5278, D(x): 0.76, D(G(z)): 0.27
# Epoch [286/300], Step [400/600], d_loss: 0.8022, g_loss: 1.4518, D(x): 0.72, D(G(z)): 0.26
# Epoch [286/300], Step [600/600], d_loss: 0.9216, g_loss: 1.6184, D(x): 0.64, D(G(z)): 0.24
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.8650, g_loss: 1.4636, D(x): 0.72, D(G(z)): 0.30
# Epoch [287/300], Step [400/600], d_loss: 0.8560, g_loss: 1.2013, D(x): 0.71, D(G(z)): 0.31
# Epoch [287/300], Step [600/600], d_loss: 0.9192, g_loss: 1.4260, D(x): 0.79, D(G(z)): 0.39
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.8498, g_loss: 1.6481, D(x): 0.70, D(G(z)): 0.26
# Epoch [288/300], Step [400/600], d_loss: 0.9354, g_loss: 1.6736, D(x): 0.65, D(G(z)): 0.25
# Epoch [288/300], Step [600/600], d_loss: 0.8031, g_loss: 2.1176, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 1.0247, g_loss: 1.6115, D(x): 0.68, D(G(z)): 0.36
# Epoch [289/300], Step [400/600], d_loss: 1.0965, g_loss: 1.3927, D(x): 0.63, D(G(z)): 0.34
# Epoch [289/300], Step [600/600], d_loss: 0.8239, g_loss: 1.6044, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 1.1278, g_loss: 1.3652, D(x): 0.67, D(G(z)): 0.39
# Epoch [290/300], Step [400/600], d_loss: 1.1537, g_loss: 1.3506, D(x): 0.70, D(G(z)): 0.42
# Epoch [290/300], Step [600/600], d_loss: 0.9913, g_loss: 1.6468, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.7837, g_loss: 1.5347, D(x): 0.70, D(G(z)): 0.25
# Epoch [291/300], Step [400/600], d_loss: 0.8406, g_loss: 1.4363, D(x): 0.66, D(G(z)): 0.26
# Epoch [291/300], Step [600/600], d_loss: 1.0776, g_loss: 1.5353, D(x): 0.61, D(G(z)): 0.27
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8722, g_loss: 1.6005, D(x): 0.71, D(G(z)): 0.25
# Epoch [292/300], Step [400/600], d_loss: 0.9640, g_loss: 1.0937, D(x): 0.70, D(G(z)): 0.33
# Epoch [292/300], Step [600/600], d_loss: 0.9545, g_loss: 1.4196, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.8668, g_loss: 1.8914, D(x): 0.68, D(G(z)): 0.26
# Epoch [293/300], Step [400/600], d_loss: 1.0035, g_loss: 1.2431, D(x): 0.70, D(G(z)): 0.35
# Epoch [293/300], Step [600/600], d_loss: 0.8929, g_loss: 1.4620, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 1.0343, g_loss: 1.3656, D(x): 0.68, D(G(z)): 0.34
# Epoch [294/300], Step [400/600], d_loss: 0.9952, g_loss: 1.4866, D(x): 0.69, D(G(z)): 0.35
# Epoch [294/300], Step [600/600], d_loss: 0.8866, g_loss: 1.6022, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9159, g_loss: 1.3105, D(x): 0.69, D(G(z)): 0.32
# Epoch [295/300], Step [400/600], d_loss: 1.0105, g_loss: 1.8052, D(x): 0.60, D(G(z)): 0.23
# Epoch [295/300], Step [600/600], d_loss: 1.1146, g_loss: 1.4653, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9257, g_loss: 1.7854, D(x): 0.67, D(G(z)): 0.25
# Epoch [296/300], Step [400/600], d_loss: 0.8380, g_loss: 1.8490, D(x): 0.72, D(G(z)): 0.26
# Epoch [296/300], Step [600/600], d_loss: 0.7737, g_loss: 1.5152, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 1.0929, g_loss: 1.6766, D(x): 0.68, D(G(z)): 0.34
# Epoch [297/300], Step [400/600], d_loss: 0.8251, g_loss: 1.3539, D(x): 0.73, D(G(z)): 0.28
# Epoch [297/300], Step [600/600], d_loss: 1.0993, g_loss: 1.5935, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.9316, g_loss: 1.3266, D(x): 0.68, D(G(z)): 0.28
# Epoch [298/300], Step [400/600], d_loss: 0.8736, g_loss: 1.4551, D(x): 0.76, D(G(z)): 0.35
# Epoch [298/300], Step [600/600], d_loss: 0.9009, g_loss: 1.6083, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.9719, g_loss: 1.3061, D(x): 0.76, D(G(z)): 0.41
# Epoch [299/300], Step [400/600], d_loss: 1.0001, g_loss: 1.5125, D(x): 0.67, D(G(z)): 0.33
# Epoch [299/300], Step [600/600], d_loss: 1.1057, g_loss: 1.2674, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0300.png
# CPU times: user 1h 15min 54s, sys: 32.3 s, total: 1h 16min 26s
# Wall time: 1h 16min 57s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
